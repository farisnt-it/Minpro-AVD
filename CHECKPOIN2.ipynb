# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Expanded_Dataset.csv")

df
# Out:
#      Year Quarter  Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0    2019      Q1     Galaxy S10            No       26396  4.212951e+06
# 1    2019      Q1  Galaxy Note10            No       25671  7.240266e+06
# 2    2019      Q1     Galaxy S20            No       16573  2.560833e+07
# 3    2019      Q1  Galaxy Note20            No        7177  2.198442e+07
# 4    2019      Q1     Galaxy S21            No       45633  1.634244e+07
# ..    ...     ...            ...           ...         ...           ...
# 995  2023      Q4  Galaxy S22 5G           Yes       36216  2.995937e+07
# 996  2022      Q2     Galaxy S21            No       33806  2.369938e+07
# 997  2022      Q1     Galaxy S10            No       23678  2.330203e+07
# 998  2023      Q4  Galaxy Note10            No       35697  1.946256e+07
# 999  2020      Q4  Galaxy Note20            No        7473  1.962177e+07
#
#      Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# 0                1.04                     57.36                      39.55
# 1                2.82                     85.80                      42.58
# 2               -0.03                     47.02                       3.78
# 3                0.84                     25.70                      23.41
# 4                2.36                     89.13                      44.43
# ..                ...                       ...                        ...
# 995              3.82                     70.59                      46.92
# 996             -0.23                     77.31                      47.51
# 997              0.58                     45.61                      43.79
# 998              2.49                     36.55                      36.44
# 999              3.88                     74.66                      27.55
#
#      Avg 5G Speed (Mbps)  Preference for 5G (%)                Region
# 0                 293.10                  55.87          Asia-Pacific
# 1                  67.46                  37.26         Latin America
# 2                  77.25                  84.66  Middle East & Africa
# 3                 105.27                  40.03         North America
# 4                 206.17                  76.88         Latin America
# ..                   ...                    ...                   ...
# 995               177.43                  63.86         Latin America
# 996               129.70                  78.41         North America
# 997               156.56                  72.06                Europe
# 998               236.39                  47.11         North America
# 999               177.22                  72.36         North America
#
# [1000 rows x 12 columns]

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# ## Missing Values

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Year                         0.0
# Quarter                      0.0
# Product Model                0.0
# 5G Capability                0.0
# Units Sold                   0.0
# Revenue ($)                  0.0
# Market Share (%)             0.0
# Regional 5G Coverage (%)     0.0
# 5G Subscribers (millions)    0.0
# Avg 5G Speed (Mbps)          0.0
# Preference for 5G (%)        0.0
# Region                       0.0
# dtype: float64

# %% [markdown]
# ## Cek Duplicated Values

# %%
df[df.duplicated()]
# Out:
#      Year Quarter  Product Model 5G Capability  Units Sold   Revenue ($)  \
# 360  2019      Q1     Galaxy S10            No       26396  4.212951e+06
# 361  2019      Q1  Galaxy Note10            No       25671  7.240266e+06
# 362  2019      Q1     Galaxy S20            No       16573  2.560833e+07
# 363  2019      Q1  Galaxy Note20            No        7177  2.198442e+07
# 364  2019      Q1     Galaxy S21            No       45633  1.634244e+07
# ..    ...     ...            ...           ...         ...           ...
# 995  2023      Q4  Galaxy S22 5G           Yes       36216  2.995937e+07
# 996  2022      Q2     Galaxy S21            No       33806  2.369938e+07
# 997  2022      Q1     Galaxy S10            No       23678  2.330203e+07
# 998  2023      Q4  Galaxy Note10            No       35697  1.946256e+07
# 999  2020      Q4  Galaxy Note20            No        7473  1.962177e+07
#
#      Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# 360              1.04                     57.36                      39.55
# 361              2.82                     85.80                      42.58
# 362             -0.03                     47.02                       3.78
# 363              0.84                     25.70                      23.41
# 364              2.36                     89.13                      44.43
# ..                ...                       ...                        ...
# 995              3.82                     70.59                      46.92
# 996             -0.23                     77.31                      47.51
# 997              0.58                     45.61                      43.79
# 998              2.49                     36.55                      36.44
# 999              3.88                     74.66                      27.55
#
#      Avg 5G Speed (Mbps)  Preference for 5G (%)                Region
# 360               293.10                  55.87          Asia-Pacific
# 361                67.46                  37.26         Latin America
# 362                77.25                  84.66  Middle East & Africa
# 363               105.27                  40.03         North America
# 364               206.17                  76.88         Latin America
# ..                   ...                    ...                   ...
# 995               177.43                  63.86         Latin America
# 996               129.70                  78.41         North America
# 997               156.56                  72.06                Europe
# 998               236.39                  47.11         North America
# 999               177.22                  72.36         North America
#
# [640 rows x 12 columns]

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      Year Quarter      Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0    2019      Q1         Galaxy S10            No       26396  4.212951e+06
# 1    2019      Q1      Galaxy Note10            No       25671  7.240266e+06
# 2    2019      Q1         Galaxy S20            No       16573  2.560833e+07
# 3    2019      Q1      Galaxy Note20            No        7177  2.198442e+07
# 4    2019      Q1         Galaxy S21            No       45633  1.634244e+07
# ..    ...     ...                ...           ...         ...           ...
# 355  2024      Q4      Galaxy S22 5G           Yes       28368  1.763926e+07
# 356  2024      Q4  Galaxy Z Fold3 5G           Yes       31313  3.361639e+07
# 357  2024      Q4      Galaxy A14 5G           Yes       10175  3.158442e+07
# 358  2024      Q4      Galaxy S23 5G           Yes       27459  4.829709e+07
# 359  2024      Q4  Galaxy Z Flip5 5G           Yes       23576  7.378715e+06
#
#      Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# 0                1.04                     57.36                      39.55
# 1                2.82                     85.80                      42.58
# 2               -0.03                     47.02                       3.78
# 3                0.84                     25.70                      23.41
# 4                2.36                     89.13                      44.43
# ..                ...                       ...                        ...
# 355              5.79                     47.78                      35.70
# 356              6.70                     59.12                      51.35
# 357              6.39                     86.40                       6.87
# 358              2.65                     73.66                      17.95
# 359              4.94                     92.65                      27.65
#
#      Avg 5G Speed (Mbps)  Preference for 5G (%)                Region
# 0                 293.10                  55.87          Asia-Pacific
# 1                  67.46                  37.26         Latin America
# 2                  77.25                  84.66  Middle East & Africa
# 3                 105.27                  40.03         North America
# 4                 206.17                  76.88         Latin America
# ..                   ...                    ...                   ...
# 355                99.55                  92.85                Europe
# 356               229.94                  66.10         North America
# 357               170.92                  87.54          Asia-Pacific
# 358               186.37                  92.94         North America
# 359               261.80                  75.18          Asia-Pacific
#
# [360 rows x 12 columns]

# %% [markdown]
# ## Outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                      Persentase Outliers
# Year                                  0.000000
# Units Sold                            0.000000
# Revenue ($)                           0.277778
# Market Share (%)                      0.000000
# Regional 5G Coverage (%)              0.000000
# 5G Subscribers (millions)             0.000000
# Avg 5G Speed (Mbps)                   0.000000
# Preference for 5G (%)                 0.000000

# %%
df
# Out:
#      Year Quarter      Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0    2019      Q1         Galaxy S10            No       26396  4.212951e+06
# 1    2019      Q1      Galaxy Note10            No       25671  7.240266e+06
# 2    2019      Q1         Galaxy S20            No       16573  2.560833e+07
# 3    2019      Q1      Galaxy Note20            No        7177  2.198442e+07
# 4    2019      Q1         Galaxy S21            No       45633  1.634244e+07
# ..    ...     ...                ...           ...         ...           ...
# 355  2024      Q4      Galaxy S22 5G           Yes       28368  1.763926e+07
# 356  2024      Q4  Galaxy Z Fold3 5G           Yes       31313  3.361639e+07
# 357  2024      Q4      Galaxy A14 5G           Yes       10175  3.158442e+07
# 358  2024      Q4      Galaxy S23 5G           Yes       27459  4.829709e+07
# 359  2024      Q4  Galaxy Z Flip5 5G           Yes       23576  7.378715e+06
#
#      Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# 0                1.04                     57.36                      39.55
# 1                2.82                     85.80                      42.58
# 2               -0.03                     47.02                       3.78
# 3                0.84                     25.70                      23.41
# 4                2.36                     89.13                      44.43
# ..                ...                       ...                        ...
# 355              5.79                     47.78                      35.70
# 356              6.70                     59.12                      51.35
# 357              6.39                     86.40                       6.87
# 358              2.65                     73.66                      17.95
# 359              4.94                     92.65                      27.65
#
#      Avg 5G Speed (Mbps)  Preference for 5G (%)                Region
# 0                 293.10                  55.87          Asia-Pacific
# 1                  67.46                  37.26         Latin America
# 2                  77.25                  84.66  Middle East & Africa
# 3                 105.27                  40.03         North America
# 4                 206.17                  76.88         Latin America
# ..                   ...                    ...                   ...
# 355                99.55                  92.85                Europe
# 356               229.94                  66.10         North America
# 357               170.92                  87.54          Asia-Pacific
# 358               186.37                  92.94         North America
# 359               261.80                  75.18          Asia-Pacific
#
# [360 rows x 12 columns]

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                      Persentase Outliers
# Year                                  0.000000
# Units Sold                            0.000000
# Revenue ($)                           0.277778
# Market Share (%)                      0.000000
# Regional 5G Coverage (%)              0.000000
# 5G Subscribers (millions)             0.000000
# Avg 5G Speed (Mbps)                   0.000000
# Preference for 5G (%)                 0.000000

# %% [markdown]
# ## Incosistent Value

# %%
df
# Out:
#      Year Quarter      Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0    2019      Q1         Galaxy S10            No       26396  4.212951e+06
# 1    2019      Q1      Galaxy Note10            No       25671  7.240266e+06
# 2    2019      Q1         Galaxy S20            No       16573  2.560833e+07
# 3    2019      Q1      Galaxy Note20            No        7177  2.198442e+07
# 4    2019      Q1         Galaxy S21            No       45633  1.634244e+07
# ..    ...     ...                ...           ...         ...           ...
# 355  2024      Q4      Galaxy S22 5G           Yes       28368  1.763926e+07
# 356  2024      Q4  Galaxy Z Fold3 5G           Yes       31313  3.361639e+07
# 357  2024      Q4      Galaxy A14 5G           Yes       10175  3.158442e+07
# 358  2024      Q4      Galaxy S23 5G           Yes       27459  4.829709e+07
# 359  2024      Q4  Galaxy Z Flip5 5G           Yes       23576  7.378715e+06
#
#      Market Share (%)  Regional 5G Coverage (%)  5G Subscribers (millions)  \
# 0                1.04                     57.36                      39.55
# 1                2.82                     85.80                      42.58
# 2               -0.03                     47.02                       3.78
# 3                0.84                     25.70                      23.41
# 4                2.36                     89.13                      44.43
# ..                ...                       ...                        ...
# 355              5.79                     47.78                      35.70
# 356              6.70                     59.12                      51.35
# 357              6.39                     86.40                       6.87
# 358              2.65                     73.66                      17.95
# 359              4.94                     92.65                      27.65
#
#      Avg 5G Speed (Mbps)  Preference for 5G (%)                Region
# 0                 293.10                  55.87          Asia-Pacific
# 1                  67.46                  37.26         Latin America
# 2                  77.25                  84.66  Middle East & Africa
# 3                 105.27                  40.03         North America
# 4                 206.17                  76.88         Latin America
# ..                   ...                    ...                   ...
# 355                99.55                  92.85                Europe
# 356               229.94                  66.10         North America
# 357               170.92                  87.54          Asia-Pacific
# 358               186.37                  92.94         North America
# 359               261.80                  75.18          Asia-Pacific
#
# [360 rows x 12 columns]

# %% [markdown]
# # Construct Data

# %% [markdown]
# "Revenue per Unit"

# %%
df['Revenue per Unit'] = df['Revenue ($)'] / df['Units Sold']
# Out:
# <ipython-input-11-b105526f8437>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Revenue per Unit'] = df['Revenue ($)'] / df['Units Sold']

# %% [markdown]
# 5G vs Non-5G

# %%
df['5G vs Non-5G'] = df['5G Capability'].apply(lambda x: '5G' if x == 'Yes' else 'Non-5G')
# Out:
# <ipython-input-12-2c6ecfe9cc3b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['5G vs Non-5G'] = df['5G Capability'].apply(lambda x: '5G' if x == 'Yes' else 'Non-5G')

# %% [markdown]
# Market Share Growth

# %%
df['Market Share Growth'] = df.groupby('Product Model')['Market Share (%)'].diff()

# %% [markdown]
# Regional 5G Adoption Rate

# %%
df['Regional 5G Adoption Rate'] = pd.cut(
    df['Regional 5G Coverage (%)'],
    bins=[0, 40, 70, 100],
    labels=['Rendah', 'Sedang', 'Tinggi'])

# %% [markdown]
# Preference for 5G (%)

# %%
df['Preference Category'] = pd.cut(
    df['Preference for 5G (%)'],
    bins=[0, 40, 70, 100],
    labels=['Rendah', 'Sedang', 'Tinggi']
)

# %% [markdown]
# # Data Reduction

# %%
df = df.drop(['Avg 5G Speed (Mbps)', '5G Subscribers (millions)'], axis=1)

# %%
df
# Out:
#      Year Quarter      Product Model 5G Capability  Units Sold   Revenue ($)  \
# 0    2019      Q1         Galaxy S10            No       26396  4.212951e+06
# 1    2019      Q1      Galaxy Note10            No       25671  7.240266e+06
# 2    2019      Q1         Galaxy S20            No       16573  2.560833e+07
# 3    2019      Q1      Galaxy Note20            No        7177  2.198442e+07
# 4    2019      Q1         Galaxy S21            No       45633  1.634244e+07
# ..    ...     ...                ...           ...         ...           ...
# 355  2024      Q4      Galaxy S22 5G           Yes       28368  1.763926e+07
# 356  2024      Q4  Galaxy Z Fold3 5G           Yes       31313  3.361639e+07
# 357  2024      Q4      Galaxy A14 5G           Yes       10175  3.158442e+07
# 358  2024      Q4      Galaxy S23 5G           Yes       27459  4.829709e+07
# 359  2024      Q4  Galaxy Z Flip5 5G           Yes       23576  7.378715e+06
#
#      Market Share (%)  Regional 5G Coverage (%)  Preference for 5G (%)  \
# 0                1.04                     57.36                  55.87
# 1                2.82                     85.80                  37.26
# 2               -0.03                     47.02                  84.66
# 3                0.84                     25.70                  40.03
# 4                2.36                     89.13                  76.88
# ..                ...                       ...                    ...
# 355              5.79                     47.78                  92.85
# 356              6.70                     59.12                  66.10
# 357              6.39                     86.40                  87.54
# 358              2.65                     73.66                  92.94
# 359              4.94                     92.65                  75.18
#
#                    Region  Revenue per Unit 5G vs Non-5G
# 0            Asia-Pacific        159.605662       Non-5G
# 1           Latin America        282.040653       Non-5G
# 2    Middle East & Africa       1545.183824       Non-5G
# 3           North America       3063.176234       Non-5G
# 4           Latin America        358.127616       Non-5G
# ..                    ...               ...          ...
# 355                Europe        621.801181           5G
# 356         North America       1073.560101           5G
# 357          Asia-Pacific       3104.120290           5G
# 358         North America       1758.880191           5G
# 359          Asia-Pacific        312.975697           5G
#
# [360 rows x 12 columns]
